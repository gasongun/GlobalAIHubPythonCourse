# %%
Grade = {"StudentList":['Jack', 'Jane', 'Mary','Rose','Jason'],
     "midterm": [],
     "project": [],
     "final":   [],
     "passingGrade": []}

input_mid = input("Enter 5 students midterm exam with space: ")
midterm = input_mid.split(" ")

for i in midterm:
    Grade["midterm"].append(int(i)) 

input_pro = input("Enter 5 students project notes with space: ")
project = input_pro.split(" ")

for i in project:
    Grade["project"].append(int(i)) 

input_final = input("Enter 5 students final exam with space: ")
final = input_final.split(" ")

for i in final:
    Grade["final"].append(int(i)) 

for i in range(len(Grade["StudentList"])):
  a =  Grade["midterm"][i]*0.3 + Grade["project"][i]*0.3 + Grade["final"][i]*0.4
  Grade["passingGrade"].append(a) 

Grade
# Out:
# Enter 5 students midterm exam with space: 12 65 87 89 36
# Enter 5 students project notes with space: 47 100 36 12 52
# Enter 5 students final exam with space: 100 90 50 60 40
# 'res = dict()\nfor key in sorted(Grade):\n    res[key] = sorted(Grade[key])\n  \n# printing result \nprint("The sorted dictionary : " + str(res))\n'

# %%
Grade
# Out:
# {'StudentList': ['Jack', 'Jane', 'Mary', 'Rose', 'Jason'],
#  'final': [100, 90, 50, 60, 40],
#  'midterm': [12, 65, 87, 89, 36],
#  'passingGrade': [57.7, 85.5, 56.9, 54.3, 42.4],
#  'project': [47, 100, 36, 12, 52]}

# %%
import pandas as pd
Grade2=pd.DataFrame(Grade)
Grade2 = Grade2.sort_values(by=['passingGrade'], ascending=False)
Grade3 = dict(Grade2)
print(Grade3)
# Out:
# {'StudentList': 1     Jane
# 0     Jack
# 2     Mary
# 3     Rose
# 4    Jason
# Name: StudentList, dtype: object, 'midterm': 1    65
# 0    12
# 2    87
# 3    89
# 4    36
# Name: midterm, dtype: int64, 'project': 1    100
# 0     47
# 2     36
# 3     12
# 4     52
# Name: project, dtype: int64, 'final': 1     90
# 0    100
# 2     50
# 3     60
# 4     40
# Name: final, dtype: int64, 'passingGrade': 1    85.5
# 0    57.7
# 2    56.9
# 3    54.3
# 4    42.4
# Name: passingGrade, dtype: float64}

# %%
res = dict()
for key in sorted(Grade):
    res[key] = sorted(Grade[key])
  
# printing result 
print("The sorted dictionary : " + str(res))
# Out:
# The sorted dictionary : {'StudentList': ['Jack', 'Jane', 'Jason', 'Mary', 'Rose'], 'final': [40, 50, 60, 90, 100], 'midterm': [12, 36, 65, 87, 89], 'passingGrade': [42.4, 54.3, 56.9, 57.7, 85.5], 'project': [12, 36, 47, 52, 100]}

# %%
myDict={"question" : ["pi sayisini virgulden sonra iki dijit olacak sekilde yaziniz: ","Atatürk kac yilinda dogmustur? : ",
                      "Atatürk Kurtulus Savasi'ni hangi ile gelerek baslatmistir ? : ","Cumhuriyet hangi yılda kurulmustur? :" ,
                      "Galatasarayın kurulus tarihi hangi yildir? :","Ingilterenin baskenti neresidir? : ","Dolar hangi ulkenin para birimidir? : ",
                      "En uzun sınıra sahip oldugumuz komsumuz hangi ulkedir? : ","Dunyada kac kıta vardır? : ","Samanyolunda kac gezegen vardir? : "], 
        "answer":["3.14","1881","samsun","1923","1905","londra","amerika","suriye","7","8"]}
answerDict = {"answer" : []}
counter=0

for i in myDict["question"]:
  print(i)
  ans = input("answer is :")
  answerDict["answer"].append(ans)
answerDict

for i in range(len(myDict["question"])):
  if answerDict["answer"][i] == myDict["answer"][i]:
    counter+=1

if counter>5:
  print("You passed!"+str(counter)+" right answer")
else:
  print("You couldn't pass. Lower than 5 answer")
# Out:
# pi sayisini virgulden sonra iki dijit olacak sekilde yaziniz:
# answer is :3.14
# Atatürk kac yilinda dogmustur? :
# answer is :1881
# Atatürk Kurtulus Savasi'ni hangi ile gelerek baslatmistir ? :
# answer is :samsun
# Cumhuriyet hangi yılda kurulmustur? :
# answer is :1923
# Galatasarayın kurulus tarihi hangi yildir? :
# answer is :1905
# Ingilterenin baskenti neresidir? :
# answer is :londra
# Dolar hangi ulkenin para birimidir? :
# answer is :amerika
# En uzun sınıra sahip oldugumuz komsumuz hangi ulkedir? :
# answer is :suriye
# Dunyada kac kıta vardır? :
# answer is :7
# Samanyolunda kac gezegen vardir? :
# answer is :8
# gectiniz9dogru cevap verdiniz.

# %%
myDict={"question" : ["pi sayisini virgulden sonra iki dijit olacak sekilde yaziniz: ","Atatürk kac yilinda dogmustur? : ",
                      "Atatürk Kurtulus Savasi'ni hangi ile gelerek baslatmistir ? : ","Cumhuriyet hangi yılda kurulmustur? :" ,
                      "Galatasarayın kurulus tarihi hangi yildir? :","Ingilterenin baskenti neresidir? : ","Dolar hangi ulkenin para birimidir? : ",
                      "En uzun sınıra sahip oldugumuz komsumuz hangi ulkedir? : ","Dunyada kac kıta vardır? : ","Samanyolunda kac gezegen vardir? : "], 
        "answer":["3.14","1881","Samsun","1923","1905","Londra","Amerika","Suriye","7","8"]}
counter=0
for i in range(len(myDict["question"])):
  q=input(myDict["question"][i])
  q=q.capitalize()
  if q==myDict["answer"][i]:
    counter+=1
    print(counter)
  else:
    print(counter)
if counter>5:
  print("You passed!"+str(counter)+" right answer")
else:
  print("You couldn't pass. Lower than 5 answer")
# Out:
# pi sayisini virgulden sonra iki dijit olacak sekilde yaziniz: 3.14
# 1
# Atatürk kac yilinda dogmustur? : 1881
# 2
# Atatürk Kurtulus Savasi'ni hangi ile gelerek baslatmistir ? : samsun
# 3
# Cumhuriyet hangi yılda kurulmustur? :1923
# 4
# Galatasarayın kurulus tarihi hangi yildir? :1905
# 5
# Ingilterenin baskenti neresidir? : londra
# 6
# Dolar hangi ulkenin para birimidir? : amerika
# 7
# En uzun sınıra sahip oldugumuz komsumuz hangi ulkedir? : suriş
# 7
# Dunyada kac kıta vardır? : 9
# 7
# Samanyolunda kac gezegen vardir? : 5
# 7
# You passed!7 right answer
